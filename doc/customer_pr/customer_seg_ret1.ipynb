# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
data = pd.read_csv('customer_segmentation.csv')

# %%
data.head(10)
# Out:
#    index InvoiceNo StockCode                          Description  Quantity  \
# 0      0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1      1    536365     71053                  WHITE METAL LANTERN         6
# 2      2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3      3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4      4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5      5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6      6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7      7    536366     22633               HAND WARMER UNION JACK         6
# 8      8    536366     22632            HAND WARMER RED POLKA DOT         6
# 9      9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 5  12/1/2010 8:26       7.65     17850.0  United Kingdom
# 6  12/1/2010 8:26       4.25     17850.0  United Kingdom
# 7  12/1/2010 8:28       1.85     17850.0  United Kingdom
# 8  12/1/2010 8:28       1.85     17850.0  United Kingdom
# 9  12/1/2010 8:34       1.69     13047.0  United Kingdom

# %%
data.columns
# Out:
# Index(['index', 'InvoiceNo', 'StockCode', 'Description', 'Quantity',
#        'InvoiceDate', 'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   index        541909 non-null  int64
#  1   InvoiceNo    541909 non-null  object
#  2   StockCode    541909 non-null  object
#  3   Description  540455 non-null  object
#  4   Quantity     541909 non-null  int64
#  5   InvoiceDate  541909 non-null  object
#  6   UnitPrice    541909 non-null  float64
#  7   CustomerID   406829 non-null  float64
#  8   Country      541909 non-null  object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 37.2+ MB

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data['Country'].unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
#        'Israel', 'Finland', 'Bahrain', 'Greece', 'Hong Kong', 'Singapore',
#        'Lebanon', 'United Arab Emirates', 'Saudi Arabia',
#        'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA',
#        'European Community', 'Malta', 'RSA'], dtype=object)

# %%
data['Description'].unique()
# Out:
# array(['WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN',
#        'CREAM CUPID HEARTS COAT HANGER', ..., 'lost',
#        'CREAM HANGING HEART T-LIGHT HOLDER',
#        'PAPER CRAFT , LITTLE BIRDIE'], shape=(4224,), dtype=object)

# %%
data['Description'].nunique()
# Out:
# 4223

# %%
data['InvoiceNo'].nunique()
# Out:
# 25900

# %%
541909 -25900
# Out:
# 516009

# %%
data['StockCode'].nunique()
# Out:
# 4070

# %%
for i in data.columns:
    print(f"{i}: {data[i].nunique()}")
# Out:
# index: 541909
# InvoiceNo: 25900
# StockCode: 4070
# Description: 4223
# Quantity: 722
# InvoiceDate: 23260
# UnitPrice: 1630
# CustomerID: 4372
# Country: 38

# %%
le_desc = LabelEncoder()

data['Description_encoded'] = le_desc.fit_transform(data['Description'])

# %%
data.head(5)
# Out:
#    index InvoiceNo StockCode                          Description  Quantity  \
# 0      0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1      1    536365     71053                  WHITE METAL LANTERN         6
# 2      2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3      3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4      4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country  Description_encoded
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom                 3918
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom                 3926
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom                  913
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom                 1910
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom                 2911

# %%
le_stock = LabelEncoder()

data['StockCode_encoded'] = le_stock.fit_transform(data['StockCode'])

# %%
data.head(5)
# Out:
#    index InvoiceNo StockCode                          Description  Quantity  \
# 0      0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1      1    536365     71053                  WHITE METAL LANTERN         6
# 2      2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3      3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4      4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country  Description_encoded  \
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom                 3918
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom                 3926
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom                  913
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom                 1910
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom                 2911
#
#    StockCode_encoded
# 0               3536
# 1               2794
# 2               3044
# 3               2985
# 4               2984

# %%
data['TotalPrice'] = data['UnitPrice'] * data['Quantity']

# %%
data.head(5)
# Out:
#    index InvoiceNo StockCode                          Description  Quantity  \
# 0      0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1      1    536365     71053                  WHITE METAL LANTERN         6
# 2      2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3      3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4      4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country  Description_encoded  \
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom                 3918
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom                 3926
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom                  913
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom                 1910
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom                 2911
#
#    StockCode_encoded  TotalPrice
# 0               3536       15.30
# 1               2794       20.34
# 2               3044       22.00
# 3               2985       20.34
# 4               2984       20.34

# %%
data = data.drop(columns=['index'])

# %%
data.head(5)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country  Description_encoded  \
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom                 3918
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom                 3926
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom                  913
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom                 1910
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom                 2911
#
#    StockCode_encoded  TotalPrice
# 0               3536       15.30
# 1               2794       20.34
# 2               3044       22.00
# 3               2985       20.34
# 4               2984       20.34

# %%
data['InvoiceDate'] = pd.to_datetime(data['InvoiceDate'])

# %%
data['Time'] = data['InvoiceDate'].dt.time

# %%
data['InvoiceDate'] = data['InvoiceDate'].dt.date

# %%
data.head(5)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#   InvoiceDate  UnitPrice  CustomerID         Country  Description_encoded  \
# 0  2010-12-01       2.55     17850.0  United Kingdom                 3918
# 1  2010-12-01       3.39     17850.0  United Kingdom                 3926
# 2  2010-12-01       2.75     17850.0  United Kingdom                  913
# 3  2010-12-01       3.39     17850.0  United Kingdom                 1910
# 4  2010-12-01       3.39     17850.0  United Kingdom                 2911
#
#    StockCode_encoded  TotalPrice      Time
# 0               3536       15.30  08:26:00
# 1               2794       20.34  08:26:00
# 2               3044       22.00  08:26:00
# 3               2985       20.34  08:26:00
# 4               2984       20.34  08:26:00

# %%
data.head(10)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7    536366     22633               HAND WARMER UNION JACK         6
# 8    536366     22632            HAND WARMER RED POLKA DOT         6
# 9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#   InvoiceDate  UnitPrice  CustomerID         Country  Description_encoded  \
# 0  2010-12-01       2.55     17850.0  United Kingdom                 3918
# 1  2010-12-01       3.39     17850.0  United Kingdom                 3926
# 2  2010-12-01       2.75     17850.0  United Kingdom                  913
# 3  2010-12-01       3.39     17850.0  United Kingdom                 1910
# 4  2010-12-01       3.39     17850.0  United Kingdom                 2911
# 5  2010-12-01       7.65     17850.0  United Kingdom                 3158
# 6  2010-12-01       4.25     17850.0  United Kingdom                 1529
# 7  2010-12-01       1.85     17850.0  United Kingdom                 1653
# 8  2010-12-01       1.85     17850.0  United Kingdom                 1650
# 9  2010-12-01       1.69     13047.0  United Kingdom                  244
#
#    StockCode_encoded  TotalPrice      Time
# 0               3536       15.30  08:26:00
# 1               2794       20.34  08:26:00
# 2               3044       22.00  08:26:00
# 3               2985       20.34  08:26:00
# 4               2984       20.34  08:26:00
# 5               1662       15.30  08:26:00
# 6                800       25.50  08:26:00
# 7               1547       11.10  08:28:00
# 8               1546       11.10  08:28:00
# 9               3305       54.08  08:34:00

# %%
data['Country'] = data['Country'].replace('EIRE', 'Ireland')

# %%
data['Country'].unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'Ireland', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
#        'Israel', 'Finland', 'Bahrain', 'Greece', 'Hong Kong', 'Singapore',
#        'Lebanon', 'United Arab Emirates', 'Saudi Arabia',
#        'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA',
#        'European Community', 'Malta', 'RSA'], dtype=object)

# %%
data.head(5)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#   InvoiceDate  UnitPrice  CustomerID         Country  Description_encoded  \
# 0  2010-12-01       2.55     17850.0  United Kingdom                 3918
# 1  2010-12-01       3.39     17850.0  United Kingdom                 3926
# 2  2010-12-01       2.75     17850.0  United Kingdom                  913
# 3  2010-12-01       3.39     17850.0  United Kingdom                 1910
# 4  2010-12-01       3.39     17850.0  United Kingdom                 2911
#
#    StockCode_encoded  TotalPrice      Time
# 0               3536       15.30  08:26:00
# 1               2794       20.34  08:26:00
# 2               3044       22.00  08:26:00
# 3               2985       20.34  08:26:00
# 4               2984       20.34  08:26:00

# %%
data['StockCode'] = data['StockCode'].str.upper()
data[data['Description']  == 'WHITE HANGING HEART T-LIGHT HOLDER']['StockCode'].unique()
# Out:
# array(['85123A'], dtype=object)

# %%
data[data['Description']  == 'RED WOOLLY HOTTIE WHITE HEART.']['StockCode'].unique()
# Out:
# array(['84029E'], dtype=object)

# %%
((data.groupby('StockCode')['Description'].nunique()) > 1 ).sum()
# Out:
# np.int64(645)

# %%
#

def calculate_rfm(data):
    """
    Compute Recency, Frequency, Monetary features.
    """
    data = data.copy()


    # Convert InvoiceDate to datetime
    data['InvoiceDate'] = pd.to_datetime(data['InvoiceDate'])

    # Compute monetary value (line item price)
    data['Amount'] = data['Quantity'] * data['UnitPrice']

    # Snapshot date (1 day after last invoice)
    snapshot_date = data['InvoiceDate'].max() + pd.Timedelta(days=1)

    rfm = data.groupby('CustomerID').agg({
        'InvoiceDate': lambda x: (snapshot_date - x.max()).days,  # Recency
        'InvoiceNo': 'nunique',                                   # Frequency
        'Amount': 'sum'                                           # Monetary
    })

    rfm.columns = ['Recency', 'Frequency', 'Monetary']
    return rfm

# %%
rfm_data.head()
# Out:
#             Recency  Frequency  Monetary
# CustomerID
# 12346.0         326          2      0.00
# 12347.0           3          7   4310.00
# 12348.0          76          4   1797.24
# 12349.0          19          1   1757.55
# 12350.0         311          1    334.40

# %%
""""
data = data.merge(
    rfm_data,
    left_on='CustomerID',
    right_index=True,
    how='left'
)

data.head(5)
"""""
# Out:
# '"\ndata = data.merge(\n    rfm_data,\n    left_on=\'CustomerID\',\n    right_index=True,\n    how=\'left\'\n)\n\ndata.head(5)\n'

# %%
data.head(5)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#   InvoiceDate  UnitPrice  CustomerID         Country  Description_encoded  \
# 0  2010-12-01       2.55     17850.0  United Kingdom                 3918
# 1  2010-12-01       3.39     17850.0  United Kingdom                 3926
# 2  2010-12-01       2.75     17850.0  United Kingdom                  913
# 3  2010-12-01       3.39     17850.0  United Kingdom                 1910
# 4  2010-12-01       3.39     17850.0  United Kingdom                 2911
#
#    StockCode_encoded  TotalPrice      Time
# 0               3536       15.30  08:26:00
# 1               2794       20.34  08:26:00
# 2               3044       22.00  08:26:00
# 3               2985       20.34  08:26:00
# 4               2984       20.34  08:26:00

# %%
data.shape
# Out:
# (541909, 12)

# %%
#data.shape
#data[['Recency', 'Frequency', 'Monetary']].head()

# %%
data.loc[data['CustomerID'] == data['CustomerID'].iloc[0],
         ['CustomerID', 'Recency', 'Frequency', 'Monetary']].head()
# Out:
#    CustomerID  Recency  Frequency  Monetary
# 0     17850.0      303         35   5288.63
# 1     17850.0      303         35   5288.63
# 2     17850.0      303         35   5288.63
# 3     17850.0      303         35   5288.63
# 4     17850.0      303         35   5288.63

# %%
customer_features = rfm_data.copy()
customer_features.head()
# Out:
#             Recency  Frequency  Monetary
# CustomerID
# 12346.0         326          2      0.00
# 12347.0           3          7   4310.00
# 12348.0          76          4   1797.24
# 12349.0          19          1   1757.55
# 12350.0         311          1    334.40

# %%
def engineer_additional_features(data):
    """Create advanced customer-level features beyond RFM."""
    df = data.copy()
    df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
    df['Amount'] = df['Quantity'] * df['UnitPrice']

    def customer_features(x):
        # Product Diversity
        unique_products = x['StockCode'].nunique()
        variety_index = unique_products / x['Quantity'].sum() if x['Quantity'].sum() > 0 else 0

        # Purchasing Patterns
        invoices = x.groupby('InvoiceNo')['Quantity'].sum()
        avg_basket_size = invoices.mean() if not invoices.empty else 0
        avg_order_value = x['Amount'].sum() / x['InvoiceNo'].nunique() if x['InvoiceNo'].nunique() > 0 else 0
        price_mean = x['UnitPrice'].mean() if not x['UnitPrice'].empty else 0
        price_std = x['UnitPrice'].std() if not x['UnitPrice'].empty else 0
        return_rate = (x['Quantity'] < 0).sum() / len(x) if len(x) > 0 else 0

        # Temporal Features
        dates = x['InvoiceDate'].sort_values()
        active_days = (dates.max() - dates.min()).days if len(dates) > 1 else 0
        active_months = dates.dt.to_period('M').nunique() if not dates.empty else 0
        interpurchase = dates.diff().dt.days
        mean_interpurchase = interpurchase.mean() if len(interpurchase) > 1 else 0
        weekend_ratio = (dates.dt.weekday >= 5).mean() if not dates.empty else 0
        morning_ratio = ((dates.dt.hour >= 6) & (dates.dt.hour < 12)).mean() if not dates.empty else 0

        # Geographical Features
        num_countries = x['Country'].nunique()

        return pd.Series({
            'UniqueProducts': unique_products,
            'VarietyIndex': variety_index,
            'AvgBasketSize': avg_basket_size,
            'AvgOrderValue': avg_order_value,
            'PriceMean': price_mean,
            'PriceStd': price_std,
            'ReturnRate': return_rate,
            'ActiveDays': active_days,
            'ActiveMonths': active_months,
            'MeanInterpurchaseTime': mean_interpurchase,
            'WeekendPurchaseRatio': weekend_ratio,
            'MorningPurchaseRatio': morning_ratio,
            'NumCountries': num_countries
        })

    feature_data = df.groupby('CustomerID').apply(customer_features)
    return feature_data

# %%
advanced_features.shape
# Out:
# (4372, 13)

# %%
advanced_features.head(10)
# Out:
#             UniqueProducts  VarietyIndex  AvgBasketSize  AvgOrderValue  \
# CustomerID
# 12346.0                1.0      0.000000       0.000000       0.000000
# 12347.0              103.0      0.041904     351.142857     615.714286
# 12348.0               22.0      0.009398     585.250000     449.310000
# 12349.0               73.0      0.115689     631.000000    1757.550000
# 12350.0               17.0      0.086294     197.000000     334.400000
# 12352.0               59.0      0.125532      42.727273     140.491818
# 12353.0                4.0      0.200000      20.000000      89.000000
# 12354.0               58.0      0.109434     530.000000    1079.400000
# 12355.0               13.0      0.054167     240.000000     459.400000
# 12356.0               53.0      0.033312     530.333333     937.143333
#
#             PriceMean   PriceStd  ReturnRate  ActiveDays  ActiveMonths  \
# CustomerID
# 12346.0      1.040000   0.000000    0.500000         0.0           1.0
# 12347.0      2.644011   2.255381    0.000000       365.0           7.0
# 12348.0      5.764839  13.400323    0.000000       283.0           4.0
# 12349.0      8.289041  35.028021    0.000000         0.0           1.0
# 12350.0      3.841176   9.334751    0.000000         0.0           1.0
# 12352.0     23.274737  70.438671    0.105263       260.0           4.0
# 12353.0      6.075000   4.516175    0.000000         0.0           1.0
# 12354.0      4.503793   4.342806    0.000000         0.0           1.0
# 12355.0      4.203846   3.464490    0.000000         0.0           1.0
# 12356.0      3.201186   3.963854    0.000000       303.0           3.0
#
#             MeanInterpurchaseTime  WeekendPurchaseRatio  MorningPurchaseRatio  \
# CustomerID
# 12346.0                  0.000000              0.000000                   0.0
# 12347.0                  2.016575              0.000000                   0.0
# 12348.0                  9.433333              0.096774                   0.0
# 12349.0                  0.000000              0.000000                   0.0
# 12350.0                  0.000000              0.000000                   0.0
# 12352.0                  2.765957              0.000000                   0.0
# 12353.0                  0.000000              0.000000                   0.0
# 12354.0                  0.000000              0.000000                   0.0
# 12355.0                  0.000000              0.000000                   0.0
# 12356.0                  5.224138              0.000000                   0.0
#
#             NumCountries
# CustomerID
# 12346.0              1.0
# 12347.0              1.0
# 12348.0              1.0
# 12349.0              1.0
# 12350.0              1.0
# 12352.0              1.0
# 12353.0              1.0
# 12354.0              1.0
# 12355.0              1.0
# 12356.0              1.0

# %%
# numcontries unique values  
advanced_features['NumCountries'].nunique()
# Out:
# 2

# %%
# Combine RFM + advanced features
customer_features = rfm_data.join(advanced_features, how='left')

# Optional: reset index so CustomerID becomes a column
customer_features = customer_features.reset_index()
customer_features.head()
# Out:
#    CustomerID  Recency  Frequency  Monetary  UniqueProducts  VarietyIndex  \
# 0     12346.0      326          2      0.00             1.0      0.000000
# 1     12347.0        3          7   4310.00           103.0      0.041904
# 2     12348.0       76          4   1797.24            22.0      0.009398
# 3     12349.0       19          1   1757.55            73.0      0.115689
# 4     12350.0      311          1    334.40            17.0      0.086294
#
#    AvgBasketSize  AvgOrderValue  PriceMean   PriceStd  ReturnRate  ActiveDays  \
# 0       0.000000       0.000000   1.040000   0.000000         0.5         0.0
# 1     351.142857     615.714286   2.644011   2.255381         0.0       365.0
# 2     585.250000     449.310000   5.764839  13.400323         0.0       283.0
# 3     631.000000    1757.550000   8.289041  35.028021         0.0         0.0
# 4     197.000000     334.400000   3.841176   9.334751         0.0         0.0
#
#    ActiveMonths  MeanInterpurchaseTime  WeekendPurchaseRatio  \
# 0           1.0               0.000000              0.000000
# 1           7.0               2.016575              0.000000
# 2           4.0               9.433333              0.096774
# 3           1.0               0.000000              0.000000
# 4           1.0               0.000000              0.000000
#
#    MorningPurchaseRatio  NumCountries
# 0                   0.0           1.0
# 1                   0.0           1.0
# 2                   0.0           1.0
# 3                   0.0           1.0
# 4                   0.0           1.0

# %%
# check how many similar products did each customer buy
#data.groupby('CustomerID')['Description'].nunique()

# %%
#is stockcode and description have one to one relationship
# data.groupby('StockCode')['Description'].nunique()

# %%
# data[data['StockCode']=='10123G']

# %%
#fill in description for the stoockcode where descripption is not one to one
# data.loc[(data['StockCode']=='gift_0001_20') & (data['Description']), 'Description'] = 'Gift Card 20'

# %%
# data[data['StockCode']=='gift_0001_20bb

# %%
#change description of index 228807 to Dotcomgiftshop Gift Voucher £20.00
# data.loc[228807, 'Description'] = 'Dotcomgiftshop Gift Voucher £20.00'

# %%
 # correct_desc = (
#     data.groupby("StockCode")["Description"]
#     .agg(lambda x: x.mode().iat[0])
# )
